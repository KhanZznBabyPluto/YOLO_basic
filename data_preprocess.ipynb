# %%
import tensorflow as tf

import numpy as np

# %%
filenames = ['/home/ansar/vscode_projects/pet_projects/Challenge/Waymo/individual_files_training_segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord',
            '/home/ansar/vscode_projects/pet_projects/Challenge/Waymo/individual_files_training_segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord',
            '/home/ansar/vscode_projects/pet_projects/Challenge/Waymo/individual_files_testing_segment-10149575340910243572_2720_000_2740_000_with_camera_labels.tfrecord']

raw_dataset = tf.data.TFRecordDataset(filenames)
raw_dataset
# Out:
# <TFRecordDatasetV2 element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')
